# %%
import pandas as pd
import numpy as np

#1

df = pd.read_csv('mower_market_snapshot.csv', sep=';')
df
# Out:
#        capacity  failure_rate     id      margin       price  \
# 0     10.492623      0.042528  18377  633.766584  828.802103
# 1     20.273730      0.037896  19363  731.576817  882.894916
# 2     20.190457      0.039111  19641  741.218202  919.355522
# 3     27.220131      0.041303  18728  654.255635  817.085097
# 4     16.370911      0.037938  18722  703.094527  844.581465
# ...         ...           ...    ...         ...         ...
# 1394  44.959895      0.234647  18451   63.662561   75.161102
# 1395  59.356058      0.253694  18663   64.014543   75.395132
# 1396  67.865222      0.228935  19169   62.132035  810.883148
# 1397  66.855435      0.244948  18946   58.697122   68.491318
# 1398  54.712713      0.177143  19017   64.259212   74.955428
#
#                prod_cost product_type quality warranty  market_share  \
# 0     195.03551928211797  auto-portee     Low     3ans      0.006360
# 1     151.31809934886763  auto-portee     Low   3 ans.      0.006840
# ...

# %%
#2

df.head(2)
# Out:
#     capacity  failure_rate     id      margin       price           prod_cost  \
# 0  10.492623      0.042528  18377  633.766584  828.802103  195.03551928211797
# 1  20.273730      0.037896  19363  731.576817  882.894916  151.31809934886763
#
#   product_type quality warranty  market_share  attractiveness
# 0  auto-portee     Low     3ans       0.00636        0.650648
# 1  auto-portee     Low   3 ans.       0.00684        0.699792

# %%
df.describe()
# Out:
#           capacity  failure_rate            id       margin        price  \
# count  1399.000000   1399.000000   1399.000000  1399.000000  1399.000000
# mean     47.663266      0.166448  18958.000000   186.262609   260.075165
# std      19.840501      0.073605    404.000825   191.011102   259.949127
# min       0.013884      0.028906  18259.000000    52.943989    62.162200
# 25%      35.853890      0.095678  18608.500000    62.247602    73.379425
# 50%      50.309242      0.199796  18958.000000    66.299672    78.439753
# 75%      61.905015      0.228011  19307.500000   265.370973   384.265263
# max     104.614865      0.302465  19657.000000   790.012898   964.973926
#
#        market_share  attractiveness
# count   1399.000000     1399.000000
# mean       0.002144        0.636507
# std        0.001790        0.124016
# min        0.000564        0.297384
# 25%        0.001135        0.549369
# 50%        0.001399        0.641351
# 75%        0.002446        0.726746
# ...

# %%
df.tail(3)
# Out:
#        capacity  failure_rate     id     margin       price  \
# 1396  67.865222      0.228935  19169  62.132035  810.883148
# 1397  66.855435      0.244948  18946  58.697122   68.491318
# 1398  54.712713      0.177143  19017  64.259212   74.955428
#
#                prod_cost product_type quality warranty  market_share  \
# 1396             unknown      essence     Low     1an.      0.001243
# 1397   9.794196773761458      essence     Low     1 an      0.001644
# 1398  10.696216086742934      essence     Low     1an.      0.001022
#
#       attractiveness
# 1396        0.655622
# 1397        0.867537
# 1398        0.538969

# %%
df.iloc[-3:]
# Out:
#        capacity  failure_rate     id     margin       price  \
# 1396  67.865222      0.228935  19169  62.132035  810.883148
# 1397  66.855435      0.244948  18946  58.697122   68.491318
# 1398  54.712713      0.177143  19017  64.259212   74.955428
#
#                prod_cost product_type quality warranty  market_share  \
# 1396             unknown      essence     Low     1an.      0.001243
# 1397   9.794196773761458      essence     Low     1 an      0.001644
# 1398  10.696216086742934      essence     Low     1an.      0.001022
#
#       attractiveness
# 1396        0.655622
# 1397        0.867537
# 1398        0.538969

# %%
df.iloc[:3]
# Out:
#     capacity  failure_rate     id      margin       price           prod_cost  \
# 0  10.492623      0.042528  18377  633.766584  828.802103  195.03551928211797
# 1  20.273730      0.037896  19363  731.576817  882.894916  151.31809934886763
# 2  20.190457      0.039111  19641  741.218202  919.355522  178.13731921134948
#
#   product_type quality warranty  market_share  attractiveness
# 0  auto-portee     Low     3ans      0.006360        0.650648
# 1  auto-portee     Low   3 ans.      0.006840        0.699792
# 2  auto-portee     Low    3_ans      0.006179        0.632129

# %%
df.loc[:6, 'id':'price']
# Out:
#       id      margin       price
# 0  18377  633.766584  828.802103
# 1  19363  731.576817  882.894916
# 2  19641  741.218202  919.355522
# 3  18728  654.255635  817.085097
# 4  18722  703.094527  844.581465
# 5  18268  728.284617  905.297503
# 6  18448  757.351286  930.615022

# %%
df.loc[:6, ('id', 'quality')]
# Out:
#       id quality
# 0  18377     Low
# 1  19363     Low
# 2  19641     Low
# 3  18728     Low
# 4  18722  Medium
# 5  18268  Medium
# 6  18448   Hight

# %%
df.loc[:, ['id', 'quality', 'warranty']]
# Out:
#          id quality warranty
# 0     18377     Low     3ans
# 1     19363     Low   3 ans.
# 2     19641     Low    3_ans
# 3     18728     Low   3 anss
# 4     18722  Medium    3ans.
# ...     ...     ...      ...
# 1394  18451  Medium     1 an
# 1395  18663     Low     1ans
# 1396  19169     Low     1an.
# 1397  18946     Low     1 an
# 1398  19017     Low     1an.
#
# [1399 rows x 3 columns]

# %%
df.loc[:,['margin','price']].iloc[2:8]
# Out:
#        margin       price
# 2  741.218202  919.355522
# 3  654.255635  817.085097
# 4  703.094527  844.581465
# 5  728.284617  905.297503
# 6  757.351286  930.615022
# 7  633.515449  818.075591

# %%
df.loc[df.index[3], 'id']
# Out:
# 18728

# %%
df[df["quality"].isin(["Low"])]
# Out:
#        capacity  failure_rate     id      margin       price  \
# 0     10.492623      0.042528  18377  633.766584  828.802103
# 1     20.273730      0.037896  19363  731.576817  882.894916
# 2     20.190457      0.039111  19641  741.218202  919.355522
# 3     27.220131      0.041303  18728  654.255635  817.085097
# 7      8.676314      0.042066  18943  633.515449  818.075591
# ...         ...           ...    ...         ...         ...
# 1393  40.831294      0.217289  18950   62.296416   69.391858
# 1395  59.356058      0.253694  18663   64.014543   75.395132
# 1396  67.865222      0.228935  19169   62.132035  810.883148
# 1397  66.855435      0.244948  18946   58.697122   68.491318
# 1398  54.712713      0.177143  19017   64.259212   74.955428
#
#                prod_cost product_type quality warranty  market_share  \
# 0     195.03551928211797  auto-portee     Low     3ans      0.006360
# 1     151.31809934886763  auto-portee     Low   3 ans.      0.006840
# ...

# %%
df.sort_values(by="capacity", ascending=True)
# Out:
#         capacity  failure_rate     id      margin       price  \
# 101     0.013884      0.036738  18693  681.438480  852.583195
# 124     0.014235      0.037153  18585  624.478314  786.026582
# 15      0.014320      0.040453  19275  723.267667  932.020559
# 106     0.015932      0.031746  18794  709.438597  871.183880
# 128     0.016112      0.036578  18889  684.398858  854.055851
# ...          ...           ...    ...         ...         ...
# 833    90.847604      0.225507  18615   68.655024   80.367723
# 709    93.720276      0.232029  19358   61.283924   72.558648
# 1364   94.190711      0.226721  19348   65.009978   75.624378
# 818    95.100035      0.232960  18476   61.929406   72.046755
# 808   104.614865      0.196455  18966   65.249862   77.462485
#
#                prod_cost product_type quality warranty  market_share  \
# 101   171.14471481439216  auto-portee     Low    3ans.      0.005851
# 124   161.54826823781949  auto-portee     Low    3ans.      0.006297
# ...

# %%
df[df['capacity'] >60]
# Out:
#        capacity  failure_rate     id      margin       price  \
# 337   64.414413      0.083212  18367  281.515090  404.679728
# 401   61.205768      0.094508  18974  258.142164  382.374023
# 407   70.603826      0.095505  18921  290.670107  407.434424
# 434   62.548564      0.101284  18566  324.314855  395.969504
# 474   61.613508      0.097596  19623  270.732303  382.325570
# ...         ...           ...    ...         ...         ...
# 1382  64.262408      0.232493  18880   65.147208   76.341530
# 1385  65.996715      0.234680  19569   62.518795   73.461685
# 1392  61.018405      0.193229  18572   64.671915   76.931706
# 1396  67.865222      0.228935  19169   62.132035  810.883148
# 1397  66.855435      0.244948  18946   58.697122   68.491318
#
#                prod_cost product_type quality warranty  market_share  \
# 337   123.16463831221323   electrique   Hight     2ans      0.002368
# 401   124.23185871844714   electrique  Medium    2_ans      0.002827
# ...

# %%
df.loc[df['capacity']>60, :]
# Out:
#        capacity  failure_rate     id      margin       price  \
# 337   64.414413      0.083212  18367  281.515090  404.679728
# 401   61.205768      0.094508  18974  258.142164  382.374023
# 407   70.603826      0.095505  18921  290.670107  407.434424
# 434   62.548564      0.101284  18566  324.314855  395.969504
# 474   61.613508      0.097596  19623  270.732303  382.325570
# ...         ...           ...    ...         ...         ...
# 1382  64.262408      0.232493  18880   65.147208   76.341530
# 1385  65.996715      0.234680  19569   62.518795   73.461685
# 1392  61.018405      0.193229  18572   64.671915   76.931706
# 1396  67.865222      0.228935  19169   62.132035  810.883148
# 1397  66.855435      0.244948  18946   58.697122   68.491318
#
#                prod_cost product_type quality warranty  market_share  \
# 337   123.16463831221323   electrique   Hight     2ans      0.002368
# 401   124.23185871844714   electrique  Medium    2_ans      0.002827
# ...

# %%
df[df['capacity'].isin([60,70])]    ????
# Out:
# Empty DataFrame
# Columns: [capacity, failure_rate, id, margin, price, prod_cost, product_type, quality, warranty, market_share, attractiveness]
# Index: []

# %%
df.dropna()
# Out:
#        capacity  failure_rate     id      margin       price  \
# 0     10.492623      0.042528  18377  633.766584  828.802103
# 1     20.273730      0.037896  19363  731.576817  882.894916
# 2     20.190457      0.039111  19641  741.218202  919.355522
# 3     27.220131      0.041303  18728  654.255635  817.085097
# 4     16.370911      0.037938  18722  703.094527  844.581465
# ...         ...           ...    ...         ...         ...
# 1394  44.959895      0.234647  18451   63.662561   75.161102
# 1395  59.356058      0.253694  18663   64.014543   75.395132
# 1396  67.865222      0.228935  19169   62.132035  810.883148
# 1397  66.855435      0.244948  18946   58.697122   68.491318
# 1398  54.712713      0.177143  19017   64.259212   74.955428
#
#                prod_cost product_type quality warranty  market_share  \
# 0     195.03551928211797  auto-portee     Low     3ans      0.006360
# 1     151.31809934886763  auto-portee     Low   3 ans.      0.006840
# ...

# %%
df.isnull()
# Out:
#       capacity  failure_rate     id  margin  price  prod_cost  product_type  \
# 0        False         False  False   False  False      False         False
# 1        False         False  False   False  False      False         False
# 2        False         False  False   False  False      False         False
# 3        False         False  False   False  False      False         False
# 4        False         False  False   False  False      False         False
# ...        ...           ...    ...     ...    ...        ...           ...
# 1394     False         False  False   False  False      False         False
# 1395     False         False  False   False  False      False         False
# 1396     False         False  False   False  False      False         False
# 1397     False         False  False   False  False      False         False
# 1398     False         False  False   False  False      False         False
#
#       quality  warranty  market_share  attractiveness
# ...

# %%
df.loc[:10, ('id', 'price','market_share')]
# Out:
#        id       price  market_share
# 0   18377  828.802103      0.006360
# 1   19363  882.894916      0.006840
# 2   19641  919.355522      0.006179
# 3   18728  817.085097      0.007925
# 4   18722  844.581465      0.007406
# 5   18268  905.297503      0.007596
# 6   18448  930.615022      0.007488
# 7   18943  818.075591      0.005291
# 8   19640  816.774028      0.006063
# 9   19559  814.799650      0.005700
# 10  19560  785.615675      0.007457

# %%
df.apply(lambda x: x*10)
# Out:
#         capacity  failure_rate      id       margin        price  \
# 0     104.926233      0.425280  183770  6337.665842  8288.021035
# 1     202.737304      0.378964  193630  7315.768166  8828.949159
# 2     201.904569      0.391112  196410  7412.182025  9193.555217
# 3     272.201310      0.413031  187280  6542.556354  8170.850970
# 4     163.709111      0.379382  187220  7030.945266  8445.814645
# ...          ...           ...     ...          ...          ...
# 1394  449.598945      2.346469  184510   636.625610   751.611015
# 1395  593.560581      2.536937  186630   640.145431   753.951318
# 1396  678.652221      2.289345  191690   621.320349  8108.831484
# 1397  668.554355      2.449479  189460   586.971216   684.913184
# 1398  547.127128      1.771434  190170   642.592122   749.554283
#
#                                               prod_cost  \
# 0     195.03551928211797195.03551928211797195.035519...
# 1     151.31809934886763151.31809934886763151.318099...
# ...

# %%
df1= df.copy()
df2 = pd.concat([df1,df])
df2
# Out:
#        capacity  failure_rate     id      margin       price  \
# 0     10.492623      0.042528  18377  633.766584  828.802103
# 1     20.273730      0.037896  19363  731.576817  882.894916
# 2     20.190457      0.039111  19641  741.218202  919.355522
# 3     27.220131      0.041303  18728  654.255635  817.085097
# 4     16.370911      0.037938  18722  703.094527  844.581465
# ...         ...           ...    ...         ...         ...
# 1394  44.959895      0.234647  18451   63.662561   75.161102
# 1395  59.356058      0.253694  18663   64.014543   75.395132
# 1396  67.865222      0.228935  19169   62.132035  810.883148
# 1397  66.855435      0.244948  18946   58.697122   68.491318
# 1398  54.712713      0.177143  19017   64.259212   74.955428
#
#                prod_cost product_type quality warranty  market_share  \
# 0     195.03551928211797  auto-portee     Low     3ans      0.006360
# 1     151.31809934886763  auto-portee     Low   3 ans.      0.006840
# ...

# %%
df1= df.copy()
df3 = pd.concat([df1,df], join = 'inner')
df3
# Out:
#        capacity  failure_rate     id      margin       price  \
# 0     10.492623      0.042528  18377  633.766584  828.802103
# 1     20.273730      0.037896  19363  731.576817  882.894916
# 2     20.190457      0.039111  19641  741.218202  919.355522
# 3     27.220131      0.041303  18728  654.255635  817.085097
# 4     16.370911      0.037938  18722  703.094527  844.581465
# ...         ...           ...    ...         ...         ...
# 1394  44.959895      0.234647  18451   63.662561   75.161102
# 1395  59.356058      0.253694  18663   64.014543   75.395132
# 1396  67.865222      0.228935  19169   62.132035  810.883148
# 1397  66.855435      0.244948  18946   58.697122   68.491318
# 1398  54.712713      0.177143  19017   64.259212   74.955428
#
#                prod_cost product_type quality warranty  market_share  \
# 0     195.03551928211797  auto-portee     Low     3ans      0.006360
# 1     151.31809934886763  auto-portee     Low   3 ans.      0.006840
# ...

# %%
df.groupby('id')

# %%
df.groupby('id').sum()
# Out:
#         capacity  failure_rate      margin       price  market_share  \
# id
# 18259  66.180234      0.249758   61.182062   71.867486      0.001540
# 18260  61.422331      0.256102   66.609965   78.048399      0.001030
# 18261  35.314779      0.089054  276.596330  369.843472      0.002929
# 18262   0.059048      0.241700   58.573978   68.418652      0.001324
# 18263  55.215627      0.174159   61.859634   73.565985      0.001239
# ...          ...           ...         ...         ...           ...
# 19653  81.862100      0.225308   67.192433   78.005512      0.001149
# 19654  39.495184      0.088142  286.212806  393.094171      0.002319
# 19655  21.433848      0.042433  730.466258  894.143074      0.007247
# 19656  83.180478      0.299144   60.513745   73.126677      0.001294
# 19657   0.057403      0.209684   57.990321   73.790139      0.001254
#
#        attractiveness
# id
# 18259        0.812690
# 18260        0.543665
# 18261        0.763196
# 18262        0.698436
# ...

# %%
df.groupby(['id','price']).sum()
# Out:
#                    capacity  failure_rate      margin  market_share  \
# id    price
# 18259 71.867486   66.180234      0.249758   61.182062      0.001540
# 18260 78.048399   61.422331      0.256102   66.609965      0.001030
# 18261 369.843472  35.314779      0.089054  276.596330      0.002929
# 18262 68.418652    0.059048      0.241700   58.573978      0.001324
# 18263 73.565985   55.215627      0.174159   61.859634      0.001239
# ...                     ...           ...         ...           ...
# 19653 78.005512   81.862100      0.225308   67.192433      0.001149
# 19654 393.094171  39.495184      0.088142  286.212806      0.002319
# 19655 894.143074  21.433848      0.042433  730.466258      0.007247
# 19656 73.126677   83.180478      0.299144   60.513745      0.001294
# 19657 73.790139    0.057403      0.209684   57.990321      0.001254
#
#                   attractiveness
# id    price
# 18259 71.867486         0.812690
# 18260 78.048399         0.543665
# ...

# %%
#3

values = pd.to_numeric(df["prod_cost"], errors="coerce")
display(df[values.isna()])
display(df[values < 0])
# Out:
#        capacity  failure_rate     id      margin       price prod_cost  \
# 100   28.029561      0.040033  18993  746.108663  350.216029   unknown
# 107   31.019904      0.038149  19522  658.116184  411.087712       NaN
# 135   23.340049      0.039023  19596  726.196516  396.773981       NaN
# 154   26.317938      0.098641  19642  272.038610  865.688164   unknown
# 166   39.703060      0.073723  18870  248.010000   70.271198   unknown
# 170   34.857361      0.114097  18964  241.552664   72.970497       NaN
# 232   41.875278      0.096177  18736  291.932051  891.665482       NaN
# 280   33.383391      0.091738  18359  260.868096  869.049664       NaN
# 331   35.137522      0.093361  19251  262.668491   77.213051       NaN
# 471   44.813757      0.102862  18379  259.776821   72.035083       NaN
# 479   36.259976      0.105738  18620  288.507312   74.897367   unknown
# 532   40.218428      0.091096  18555  259.753146  848.659019   unknown
# ...

# %%
#4

df.isnull().sum()
# Out:
# capacity           0
# failure_rate       0
# id                 0
# margin             0
# price              0
# prod_cost         18
# product_type       0
# quality            0
# warranty           0
# market_share       0
# attractiveness     0
# Essence            0
# Electrique         0
# Auto_portee        0
# dtype: int64

# %%
#5  

df.fillna(df.mean())
# Out:
#        capacity  failure_rate     id      margin       price  \
# 0     10.492623      0.042528  18377  633.766584  828.802103
# 1     20.273730      0.037896  19363  731.576817  882.894916
# 2     20.190457      0.039111  19641  741.218202  919.355522
# 3     27.220131      0.041303  18728  654.255635  817.085097
# 4     16.370911      0.037938  18722  703.094527  844.581465
# ...         ...           ...    ...         ...         ...
# 1394  44.959895      0.234647  18451   63.662561   75.161102
# 1395  59.356058      0.253694  18663   64.014543   75.395132
# 1396  67.865222      0.228935  19169   62.132035  810.883148
# 1397  66.855435      0.244948  18946   58.697122   68.491318
# 1398  54.712713      0.177143  19017   64.259212   74.955428
#
#                prod_cost  product_type quality warranty  market_share  \
# 0     195.03551928211797             1     Low     3ans      0.006360
# 1     151.31809934886763             1     Low   3 ans.      0.006840
# ...

# %%
#6

df["warranty"].unique()
df
# Out:
#        capacity  failure_rate     id      margin       price  \
# 0     10.492623      0.042528  18377  633.766584  828.802103
# 1     20.273730      0.037896  19363  731.576817  882.894916
# 2     20.190457      0.039111  19641  741.218202  919.355522
# 3     27.220131      0.041303  18728  654.255635  817.085097
# 4     16.370911      0.037938  18722  703.094527  844.581465
# ...         ...           ...    ...         ...         ...
# 1394  44.959895      0.234647  18451   63.662561   75.161102
# 1395  59.356058      0.253694  18663   64.014543   75.395132
# 1396  67.865222      0.228935  19169   62.132035  810.883148
# 1397  66.855435      0.244948  18946   58.697122   68.491318
# 1398  54.712713      0.177143  19017   64.259212   74.955428
#
#                prod_cost product_type quality warranty  market_share  \
# 0     195.03551928211797            1     Low        3      0.006360
# 1     151.31809934886763            1     Low        3      0.006840
# ...

# %%
#7 #8

df["warranty"] = df["warranty"].apply(lambda x: x[0])
df
# Out:
#        capacity  failure_rate     id      margin       price  \
# 0     10.492623      0.042528  18377  633.766584  828.802103
# 1     20.273730      0.037896  19363  731.576817  882.894916
# 2     20.190457      0.039111  19641  741.218202  919.355522
# 3     27.220131      0.041303  18728  654.255635  817.085097
# 4     16.370911      0.037938  18722  703.094527  844.581465
# ...         ...           ...    ...         ...         ...
# 1394  44.959895      0.234647  18451   63.662561   75.161102
# 1395  59.356058      0.253694  18663   64.014543   75.395132
# 1396  67.865222      0.228935  19169   62.132035  810.883148
# 1397  66.855435      0.244948  18946   58.697122   68.491318
# 1398  54.712713      0.177143  19017   64.259212   74.955428
#
#                prod_cost product_type quality warranty  market_share  \
# 0     195.03551928211797            1     Low        3      0.006360
# 1     151.31809934886763            1     Low        3      0.006840
# ...

# %%
#9 Traiter la colonne price afin d'avoir 3 catégories :   


price = df["price"]
se_price=pd.Series(price)
bin = [0,301, 501, 1000000]
se1 = pd.cut(se_price,bin)
se1
# Out:
# 0       (501, 1000000]
# 1       (501, 1000000]
# 2       (501, 1000000]
# 3       (501, 1000000]
# 4       (501, 1000000]
#              ...
# 1394          (0, 301]
# 1395          (0, 301]
# 1396    (501, 1000000]
# 1397          (0, 301]
# 1398          (0, 301]
# Name: price, Length: 1399, dtype: category
# Categories (3, interval[int64]): [(0, 301] < (301, 501] < (501, 1000000]]

# %%
#10

df.loc[df.product_type=='essence', 'product_type'] = 1
df.loc[df.product_type=='auto-portee', 'product_type'] = 2
df.loc[df.product_type=='electrique', 'product_type'] = 3
df
# Out:
#        capacity  failure_rate     id      margin       price  \
# 0     10.492623      0.042528  18377  633.766584  828.802103
# 1     20.273730      0.037896  19363  731.576817  882.894916
# 2     20.190457      0.039111  19641  741.218202  919.355522
# 3     27.220131      0.041303  18728  654.255635  817.085097
# 4     16.370911      0.037938  18722  703.094527  844.581465
# ...         ...           ...    ...         ...         ...
# 1394  44.959895      0.234647  18451   63.662561   75.161102
# 1395  59.356058      0.253694  18663   64.014543   75.395132
# 1396  67.865222      0.228935  19169   62.132035  810.883148
# 1397  66.855435      0.244948  18946   58.697122   68.491318
# 1398  54.712713      0.177143  19017   64.259212   74.955428
#
#                prod_cost product_type quality warranty  market_share  \
# 0     195.03551928211797            1     Low     3ans      0.006360
# 1     151.31809934886763            1     Low   3 ans.      0.006840
# ...

# %%
#11

df = df.assign(Essence=df["product_type"].apply(lambda x: 1 if x==1 else 0), Auto_portee=df["product_type"].apply(lambda x: 1 if x==3 else 0), Electrique=df["product_type"].apply(lambda x: 1 if x==2 else 0))
df.groupby(["product_type"])
df
# Out:
#        capacity  failure_rate     id      margin       price  \
# 0     10.492623      0.042528  18377  633.766584  828.802103
# 1     20.273730      0.037896  19363  731.576817  882.894916
# 2     20.190457      0.039111  19641  741.218202  919.355522
# 3     27.220131      0.041303  18728  654.255635  817.085097
# 4     16.370911      0.037938  18722  703.094527  844.581465
# ...         ...           ...    ...         ...         ...
# 1394  44.959895      0.234647  18451   63.662561   75.161102
# 1395  59.356058      0.253694  18663   64.014543   75.395132
# 1396  67.865222      0.228935  19169   62.132035  810.883148
# 1397  66.855435      0.244948  18946   58.697122   68.491318
# 1398  54.712713      0.177143  19017   64.259212   74.955428
#
#                prod_cost product_type quality warranty  market_share  \
# 0     195.03551928211797            1     Low     3ans      0.006360
# 1     151.31809934886763            1     Low   3 ans.      0.006840
# ...
